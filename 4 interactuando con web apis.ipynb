# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Interacting with Web APIs
#
# Muchos sitios web tienen API públicas que proporcionan datos a través de JSON o algún otro formato. Hay varias formas de acceder a estas API desde Python; Un método fácil de usar que recomiendo es el paquete de solicitudes.
#
# Para encontrar los últimos 30 problemas de GitHub para pandas en GitHub, podemos hacer una solicitud GET HTTP utilizando la biblioteca de solicitudes de complementos

# %%
import requests

# %%
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'

# %%
resp = requests.get(url)

# %%
resp
# Out:
# <Response [200]>

# %% [markdown]
# El método json del objeto Response devolverá un diccionario que contiene JSON analizado en objetos nativos de Python

# %%
data = resp.json()

# %%
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36365',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36365/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36365/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36365/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/36365',
#   'id': 701299812,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NDg2Nzc5NDU3',
#   'number': 36365,
#   'title': 'BUG: Python Parser skipping over items if BOM present in first element of header',
#   'user': {'login': 'asishm',
#    'id': 1978117,
#    'node_id': 'MDQ6VXNlcjE5NzgxMTc=',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/1978117?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/asishm',
#    'html_url': 'https://github.com/asishm',
# ...

# %%
data[0]['title']
# Out:
# 'BUG: Python Parser skipping over items if BOM present in first element of header'

# %% [markdown]
# Cada elemento en los datos es un diccionario que contiene todos los datos encontrados en una página de problema de GitHub (excepto los comentarios). se puede pasar los datos directamente a DataFrame y extraer campos de interés

# %%
problemas = pd.DataFrame(data, columns=['number', 'title',
                                     'labels', 'state'])

# %%
problemas
# Out:
#     number                                              title  \
# 0    36365  BUG: Python Parser skipping over items if BOM ...
# 1    36364                                  Update parsers.py
# 2    36363                  DOC: move release note for #36175
# 3    36362  REF: _unbox_scalar, _unbox_listlike for Catego...
# 4    36361  DOC: New storage_options for read_csv needs a ...
# 5    36360            BUG: MutliIndex names lost during pivot
# 6    36359  BUG: get_indexer methods return int64 instead ...
# 7    36358  Fix documentation for new float_precision on r...
# 8    36357                            Dispatch string methods
# 9    36356   DOC: Example for natural sort using key argument
# 10   36354  DEV: doctests fail on automatic int32/int64 se...
# 11   36353  BUG: DataFrame.stack does not work when MultiI...
# 12   36352  BUG: interpolate with limit keyword partially ...
# 13   36350  BUG: DataFrameGroupBy.transform with axis=1 fa...
# ...
